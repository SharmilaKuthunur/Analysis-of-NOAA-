# %% [markdown]
# # 2. Univariate Analysis

# %% [markdown]
# This notebook contains:
#
#     2.1. Statistical Overview of the Entire Dataset
#     2.2. Univariate Analysis for Categorical Variables
#     2.3. Univariate Analysis for Numerical Variables
#     2.4. Insights

# %% [markdown]
# ## 2.1. Statistical Overview of the Entire Dataset
#
# This section provides a brief statistical overview of the entire preprocessed dataset.

# %% [markdown]
# The required packages are imported over here:

# %%
import pandas as pd
import numpy as np
import plotly as ply
import plotly.express as px

# %% [markdown]
# The downloaded preprocessed dataset *Dataset for Analysis* is then read into a Pandas DataFrame:

# %%
univariate_analysis = pd.read_csv("C:\\Users\\Sharmila\\Sharmila_Kuthunur Analysis of NOAA Significant Earthquakes Dataset\\1. Preprocessing\\Dataset for Analysis.csv")

# %%
# Viewing the entire dataset

print(univariate_analysis)
# Out:
#       Unnamed: 0  Year  Tsu  Vol                              Name  Latitude  \
# 0              0 -2150    ?    ?      JORDAN: BAB-A-DARAA,AL-KARAK    31.100
# 1              1 -2000  Tsu    ?                     SYRIA: UGARIT    35.683
# 2              2 -2000    ?    ?                   TURKMENISTAN: W    38.000
# 3              3 -1610  Tsu  Vol  GREECE: THERA ISLAND (SANTORINI)    36.400
# 4              4 -1566    ?    ?           ISRAEL: ARIHA (JERICHO)    31.500
# ...          ...   ...  ...  ...                               ...       ...
# 6139        6139  2019    ?    ?         PAKISTAN: MIRPUR DISTRICT    33.106
# 6140        6140  2019    ?    ?          INDONESIA: MALUKU: AMBON    -3.450
# 6141        6141  2019    ?    ?                  TURKEY: ISTANBUL    40.890
# 6142        6142  2019    ?    ?              CHILE: SOUTH CENTRAL   -40.815
# 6143        6143  2019    ?    ?                 CHILE: CONCEPCION   -35.473
#
#       Longitude  Mag MMI Int       Country                     Region  \
# 0        35.500  7.3       ?        JORDAN       BAB-A-DARAA,AL-KARAK
# 1        35.800    ?    10.0         SYRIA                     UGARIT
# 2        58.200  7.1    10.0  TURKMENISTAN                          W
# 3        25.400    ?       ?        GREECE   THERA ISLAND (SANTORINI)
# 4        35.300    ?    10.0        ISRAEL            ARIHA (JERICHO)
# ...         ...  ...     ...           ...                        ...
# 6139     73.766  5.6       ?      PAKISTAN            MIRPUR DISTRICT
# 6140    128.347  6.5       ?     INDONESIA                     MALUKU
# 6141     28.173  5.7       ?        TURKEY                   ISTANBUL
# 6142    -72.002  6.1       ?         CHILE              SOUTH CENTRAL
# 6143    -73.162  6.8       ?         CHILE                 CONCEPCION
#
#       UpdatedYear
# 0               0
# 1             150
# 2             150
# 3             540
# 4             584
# ...           ...
# 6139         4169
# 6140         4169
# 6141         4169
# 6142         4169
# 6143         4169
#
# [6144 rows x 12 columns]

# %%
print(univariate_analysis.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6144 entries, 0 to 6143
# Data columns (total 12 columns):
# Unnamed: 0     6144 non-null int64
# Year           6144 non-null int64
# Tsu            6144 non-null object
# Vol            6144 non-null object
# Name           6144 non-null object
# Latitude       6144 non-null float64
# Longitude      6144 non-null float64
# Mag            6144 non-null object
# MMI Int        6144 non-null object
# Country        6144 non-null object
# Region         5415 non-null object
# UpdatedYear    6144 non-null int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 576.1+ KB
# None

# %%
# First five rows

print(univariate_analysis.head())
# Out:
#    Unnamed: 0  Year  Tsu  Vol                              Name  Latitude  \
# 0           0 -2150    ?    ?      JORDAN: BAB-A-DARAA,AL-KARAK    31.100
# 1           1 -2000  Tsu    ?                     SYRIA: UGARIT    35.683
# 2           2 -2000    ?    ?                   TURKMENISTAN: W    38.000
# 3           3 -1610  Tsu  Vol  GREECE: THERA ISLAND (SANTORINI)    36.400
# 4           4 -1566    ?    ?           ISRAEL: ARIHA (JERICHO)    31.500
#
#    Longitude  Mag MMI Int       Country                     Region  \
# 0       35.5  7.3       ?        JORDAN       BAB-A-DARAA,AL-KARAK
# 1       35.8    ?    10.0         SYRIA                     UGARIT
# 2       58.2  7.1    10.0  TURKMENISTAN                          W
# 3       25.4    ?       ?        GREECE   THERA ISLAND (SANTORINI)
# 4       35.3    ?    10.0        ISRAEL            ARIHA (JERICHO)
#
#    UpdatedYear
# 0            0
# 1          150
# 2          150
# 3          540
# 4          584

# %%
# Last five rows

print(univariate_analysis.tail())
# Out:
#       Unnamed: 0  Year Tsu Vol                       Name  Latitude  \
# 6139        6139  2019   ?   ?  PAKISTAN: MIRPUR DISTRICT    33.106
# 6140        6140  2019   ?   ?   INDONESIA: MALUKU: AMBON    -3.450
# 6141        6141  2019   ?   ?           TURKEY: ISTANBUL    40.890
# 6142        6142  2019   ?   ?       CHILE: SOUTH CENTRAL   -40.815
# 6143        6143  2019   ?   ?          CHILE: CONCEPCION   -35.473
#
#       Longitude  Mag MMI Int    Country            Region  UpdatedYear
# 6139     73.766  5.6       ?   PAKISTAN   MIRPUR DISTRICT         4169
# 6140    128.347  6.5       ?  INDONESIA            MALUKU         4169
# 6141     28.173  5.7       ?     TURKEY          ISTANBUL         4169
# 6142    -72.002  6.1       ?      CHILE     SOUTH CENTRAL         4169
# 6143    -73.162  6.8       ?      CHILE        CONCEPCION         4169

# %% [markdown]
# ## 2.2. Univariate Analysis of Categorical Variables
#
# This section analyzes four categorial variables: Country, Region, Tsu, and Vol. Briefly, they are -
#
#     Country: The name of the country where the earthquake occurred.
#     Region: The name of the specific region in the country where the earthquake occurred.
#     Tsu: Occurrence of tsunamis. Denoted with 'Tsu' if a tsunami occurred or '?' if it did not occur.
#     Vol: Occurrence of volcanoes. Denoted with 'Vol' if a volcano occurred or '?' if it did not occur.
#
# Tasks performed in this section are:
#
#     2.2.1. Histogram of earthquakes in each country
#     2.2.2. Histogram of earthquakes in each region
#     2.2.3. Histogram of earthquakes in the same country and region
#     2.2.4. Understanding Tsu and Vol columns

# %% [markdown]
# ### 2.2.1. Histogram of earthquakes in each country

# %%
# Number of unique countries

print(len(univariate_analysis['Country'].unique()))
# Out:
# 340

# %%
# Frequency of earthquakes in each country

univariate_analysis['Country'].value_counts()
# Out:
# CHINA                     598
# IRAN                      378
# INDONESIA                 369
# JAPAN                     345
# ITALY                     325
#                          ...
# BRITISH VIRGIN ISLANDS      1
# FIJI                        1
# NEW HAMPSHIRE               1
# INDONESIA-MALAYSIA          1
# AFGHANISTAN; INDIA          1
# Name: Country, Length: 340, dtype: int64

# %% [markdown]
# The count of earthquakes in each country can be represented as a histogram below:

# %%
# Plotting the histogram

histogram_countries = univariate_analysis['Country']
fig = px.histogram(histogram_countries, x= "Country")
fig.update_layout(
    title_text='Histogram of earthquakes in each country', # title of plot
    xaxis_title_text='Name of the Country', # xaxis label
    yaxis_title_text='Count', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig.show()
# Out:
# <div>
#
#
#             <div id="f35f83e4-f3d8-4d0d-a421-92b5b13c400d" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f35f83e4-f3d8-4d0d-a421-92b5b13c400d")) {
#                     Plotly.newPlot(
#                         'f35f83e4-f3d8-4d0d-a421-92b5b13c400d',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["JORDAN", "SYRIA", "TURKMENISTAN", "GREECE", "ISRAEL", "ITALY", "SYRIAN COASTS", "ISRAEL", "JORDAN", "ISRAEL", "LEBANON", "GREECE", "LEBANON", "GREECE", "GREECE", "GREECE", "GREECE", "IRAN", "GREECE", "ITALY", "GREECE", "INDIA", "GREECE", "TURKEY", "KYRGYZSTAN", "GREECE", "GREECE", "EGYPT", "SPAIN", "ITALY", "PORTUGAL", "EAST MEDITERRANEAN SEA", "CHINA", "CHINA", "ITALY", "CHINA", "RUSSIA", "PORTUGAL", "ALBANIA", "BULGARIA", "GEORGIA", "CHINA", "ISRAEL", "ISRAEL", "EGYPT", "CHINA", "CYPRUS", "CYPRUS", "TURKMENISTAN", "TURKEY", "TURKEY", "GREECE", "PAKISTAN", "SOUTH KOREA", "TURKEY", "ISRAEL", "TURKEY", "CHINA", "AFGHANISTAN", "GREECE", "TURKEY", "GREECE", "ALBANIA", "TURKEY", "GREECE", "ITALY", "CYPRUS", "ITALY", "SOUTH KOREA", "TURKEY", "SOUTH KOREA", "TURKEY", "TURKEY", "TURKEY", "TURKEY", "SOUTH KOREA", "CHINA", "CHINA", "GREECE", "CHINA", "GREECE", "GREECE-TURKEY", "CHINA", "ITALY", "TURKEY", "CHINA", "ITALY", "GREECE", "TURKEY", "ITALY", "TURKEY", "CHINA", "CHINA", "SOUTH KOREA", "LEBANON", "ISRAEL", "CHINA", "ITALY", "ALBANIA", "TURKEY", "TURKEY", "ALBANIA", "TURKEY", "ITALY", "CHINA", "TURKEY", "ALBANIA", "LEBANON", "TURKEY", "TURKEY", "TURKEY", "BALKANS NW", "JORDAN", "TURKEY", "GREECE", "TURKEY", "TURKEY", "TURKEY", "ITALY", "PORTUGAL", "TURKEY", "TURKEY", "TURKEY", "TUNISIA", "ISRAEL", "ISRAEL", "AZERBAIJAN", "GREECE", "TURKEY", "TURKEY", "GREECE", "INSTANBUL (CONSTANTINOPLE)", "TURKEY", "TURKEY", "THAILAND", "FRANCE", "TURKEY", "TURKEY", "LEBANON", "CHINA", "KAZAKHSTAN", "NORTH KOREA", "SOUTH KOREA", "CHINA", "BALKANS NW", "GREECE", "ALBANIA", "SYRIA", "TURKEY", "GREECE-ALBANIA", "TURKEY", "SYRIA", "TURKEY", "GREECE", "GREECE", "LEBANON", "SYRIA", "LEBANON", "GREECE", "TURKEY", "TURKEY", "TURKEY", "TURKEY", "TURKEY", "ITALY", "TURKEY", "BALKANS NW", "TURKEY", "TURKEY", "TURKEY", "CHINA", "ITALY", "IRAN", "CHINA", "IRAN", "SOUTH KOREA", "IRAQ", "JAPAN", "TURKEY", "JAPAN", "JAPAN", "TURKEY", "TURKEY", "TURKEY", "CHINA", "ARMENIA", "TURKEY", "SYRIA; ISRAEL; ASIA", "IRAN", "RUSSIA", "JAPAN", "JAPAN", "JAPAN", "ISRAEL", "SYRIA", "IRAQ", "ISRAEL", "IRAN", "JAPAN", "CHINA", "CHINA", "ITALY", "SOUTH KOREA", "CHINA", "ITALY", "GREECE", "ITALY", "ITALY", "TURKEY", "UNITED KINGDOM", "CHINA", "AFGHANISTAN; INDIA", "JAPAN", "CHINA", "TURKEY", "UZBEKISTAN", "UNITED KINGDOM", "SYRIA", "IRAQ", "TURKEY", "ITALY", "SYRIA", "IRAQ", "IRAN", "JAPAN", "ARMENIA", "ITALY", "TUNISIA", "ARMENIA", "FRANCE", "IRAN", "ARMENIA", "TUNISIA", "IRAN", "GREECE", "EGYPT", "TURKEY; ARMENIA", "IRAN", "TURKEY", "IRAQ", "IRAN", "TURKEY; ARMENIA", "JAPAN", "IRAN", "IRAN", "TURKEY", "JAPAN", "IRAN", "CHINA", "ALGERIA-MOROCCO", "EGYPT", "JAPAN", "JAPAN", "IRAN", "ARMENIA", "ITALY", "BALKANS NW", "ITALY", "IRAN", "IRAQ", "IRAN", "JAPAN", "UZBEKISTAN", "IRAN", "TURKMENISTAN", "SYRIA", "TURKMENISTAN", "IRAN", "IRAQ", "IRAN", "IRAN", "IRAQ", "ITALY", "TURKEY", "IRAN", "IRAN", "ITALY", "IRAQ", "ITALY", "SYRIA", "CHINA", "CHINA", "BALKANS NW", "CHINA", "CHINA", "ITALY", "FRANCE", "TURKEY", "IRAN-IRAQ", "IRAN-IRAQ", "TURKEY", "ICELAND", "SWITZERLAND", "CHINA", "JAPAN", "ISRAEL", "NORTH KOREA", "CHINA", "CHINA", "TURKEY", "TUNISIA", "IRAN", "IRAN", "TURKEY", "TURKEY", "UNITED KINGDOM", "IRAN", "IRAN", "CHINA", "IRAQ", "LEBANON", "TURKEY", "TURKEY", "ITALY", "IRAN", "IRAN", "CHINA", "ISRAEL", "CHINA", "EGYPT", "YEMEN", "SYRIA", "TURKEY", "IRAN", "TURKEY", "IRAQ", "ITALY", "GEORGIA", "JAPAN", "SYRIA", "TURKEY", "JAPAN", "JAPAN", "IRAN", "CHINA", "AFGHANISTAN", "TURKEY", "TURKEY", "TURKEY", "TURKEY", "ITALY", "TURKEY", "IRAN", "TURKEY", "TURKEY", "ITALY", "ITALY", "UNITED KINGDOM", "IRAN", "CHINA", "ITALY", "IRAQ", "IRAQ", "IRAQ-SYRIA", "ITALY", "AZERBAIJAN", "CHINA", "IRAQ", ...

# %% [markdown]
# ### 2.2.2. Histogram of earthquakes in each region

# %%
# Number of unique regions

print(len(univariate_analysis['Region'].unique()))
# Out:
# 2873

# %%
# Frequency of earthquakes in each region

print(univariate_analysis['Region'].value_counts())
# Out:
#  YUNNAN PROVINCE                      144
#  SICHUAN PROVINCE                      77
#  HONSHU                                60
#  CENTRAL                               59
#  NORTHERN                              51
#                                      ...
#  ZANGEZUR, NAKHITCHEVAN                 1
#  MEXICO CITY,ACAPULCO                   1
#  GANSU PROVINCE, SHANXI PROVINCE        1
#  QUEZALTENANGO, SAN MARCOS, SOLOLA      1
#  DAMGHAN-TORUD                          1
# Name: Region, Length: 2872, dtype: int64

# %% [markdown]
# The count of earthquakes in each region can be represented in the histogram below:

# %%
# Plotting the histogram

histogram_region = univariate_analysis['Region']
fig = px.histogram(histogram_region, x="Region")
fig.update_layout(
    title_text='Histogram of earthquakes in each region', # title of plot
    xaxis_title_text='Name of the Region', # xaxis label
    yaxis_title_text='Count', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig.show()
# Out:
# <div>
#
#
#             <div id="113567d7-6529-41d6-b404-1dabca17f900" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("113567d7-6529-41d6-b404-1dabca17f900")) {
#                     Plotly.newPlot(
#                         '113567d7-6529-41d6-b404-1dabca17f900',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Region=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [" BAB-A-DARAA,AL-KARAK", " UGARIT", " W", " THERA ISLAND (SANTORINI)", " ARIHA (JERICHO)", " LACUS CIMINI", null, " ARIHA (JERICHO)", " SW", " JERUSALEM", " SUR (TYRE)", " MOUNT TAYGETUS", " SUR (TYRE), SAYDA (SAIDA)", " SARONIC GULF", " MACEDONIA", " ROMAN TERRITORIES", " EUBOEA", " REY,EIVAN-E-KAY", null, " ROME", " AEGEAN SEA", " KUTCH", " DELPHI", " LYSIMACHIA", " CHIGUCHIN", " DODECANESE ISLANDS", null, " SIWA OASIS; LIBYA", " CADIZ", " LIGURIA (LIGURIE), GAULE", " CABO SAN VICENTE", null, " GANSU PROVINCE", " GANSU PROVINCE", " SABINES", " SHANDONG PROVINCE", " PANTIKAPEY", " CABO SAN VICENTE", " DYRRACHIUM", " BISONE [KAVARNA], DIONISOPOLIS [BALCHIK]", " DYOSCURIA [SUKHUMI]", " GANSU PROVINCE", " PALESTINE", " QUMRAN,ARIHA (JERICHO)", " THEBES", " SICHUAN", null, " SALAMIS", " NISA", null, " IZMIR, EFES, AYDIN, MANISA, ALASEHIR, SART", null, null, " KWANGJU", " IZNIK,IZMIT", " PALESTINE", " ANTAKYA (ANTIOCH)", " HENAN PROVINCE", " AIKHANUM", " PHILIPPI,DRAMA,KAVALA", " ANTAKYA (ANTIOCH)", " CRETE", " DURRES", " LAODICEA, HIERAPOLIS, COLOSSAE, [PAMUKKALE]", " CRETE", " POMPEI", " PAPHOS, SALAMIS", " NAPLES (NAPOLI)", " KWANGJU", " HELLESPONT", " KYONGJU", null, " GALATIA", " ANTAKYA (ANTIOCH)", " NICOMEDIA, NICAEA", " KYONGJU", " GANSU PROVINCE", " GANSU PROVINCE", " RHODES", " GANSU PROVINCE", " DODECANESE ISLANDS", " VITINIA,HELLESPONT", " YELLOW SEA", " SICILY", " IZMIR, AEGEAN ISLANDS", " GANSU PROVINCE", " VERONA,BENACO", " CRETE", null, " ROME", " S COASTS; LIBYA", " ANHUI PROVINCE", " BEIJING", " KYONGJU", " SUR (TYRE), SAYDA (SAIDA)", " AEROPOLIS", " GANSU PROVINCE", " CAMPANIA", " DURRES", " ANTAKYA (ANTIOCH)", " ANTAKYA (ANTIOCH)", " DURRES", " ANTAKYA (ANTIOCH)", " CAMPANIA", " HENAN PROVINCE", " DARDANELLES", " DURRES (DYRRACHIUM)", " BAYRUT (BEROUTH)", null, " IZMIT,NICOMEDIA", " IZNIK, IZMIT [NICOMEDIA]", " MACEDONIA", " AL-KARAK", null, " CRETE", " IZNIK,NICAEA", " NICAEA [IZNIK]", " MARMARA SEA", " BENEVENTO", " CABO SAN VICENTE", " ANTAKYA (ANTIOCH)", " ANTAKYA (ANTIOCH)", " MARMARA SEA", " UTIQUE", " PALESTINE", " JERUSALEM, PALESTINE, RAMLEH; EGYPT", null, " CRETE", " ISTANBUL (CONSTANTINOPLE)", " ISTANBUL (CONSTANTINOPLE)", " CRETE", null, " ANTAKYA (ANTIOCH)", " ANTAKYA (ANTIOCH)", " YONOK-NAGABANDHU", " VIENNE,VIVARAIS,DAUPHINE,VELAY,FOREZ", " ISTANBUL (CONSTANTINOPLE)", " MARMARA SEA", " TARABULUS (TRIPOLIS); SYRIA", " JIANGSU PROVINCE", null, " PYONGYANG", " KYONGJU", " SHAANXI PROVINCE", " MACEDONIA", " DURRES,KORINTHOS", " DURRES", null, " ANTAKYA (ANTIOCH), SAMANDAG", null, " ANTAKYA (ANTIOCH)", " ALEPPO", " CYZICUS", " MALIAKOS GULF", " SCHISMA, BOETIA", " BAYRUT (BEIRUT); EGYPT; IRAQ;SAUDI ARABIA", " HALAB (ALEPPO); TURKEY", " BAYRUT (BEIRUT)", " KOS", " ISTANBUL (CONSTANTINOPLE)", " ANTAKYA (ANTIOCH)", " MARMARA SEA", " ISTANBUL (CONSTANTINOPLE)", null, " ANCONA", " ANTAKYA (ANTIOCH)", " SLOVENIA", " ANTAKYA (ANTIOCH)", " ANTAKYA (ANTIOCH)", " ANTAKYA (ANTIOCH)", " SHAANXI PROVINCE", null, " TABRIZ", " SHAANXI PROVINCE", " QUMIS", " KYONGJU", " JAZIRAH", null, " IZMIR", " KYOTO PREFECTURE", " KUMANONADA", " ANTAKYA (ANTIOCH)", " IZNIK", " ANTAKYA (ANTIOCH)", " GANSU PROVINCE", " BAYOTSDZOR", " ISTANBUL (CONSTANTINOPLE)", null, " EIVAN-E-KAY", " CASPIAN SEA", " SHIMABARA, YATSUSHIRO, HIGO", " MINO", " OSAKA BAY", " TEVERYA (TIBERIAS), ARIHA (JERICHO)", " DIMASHQ (DAMASCUS)", " JAZIRAH", " PALESTINE; SYRIA", " KHURASAN", " N. KAGOSHIMA BAY", " HEBEI PROVINCE", " HUNAN PROVINCE", " TREVISO", " KYONGJU", " SHAANXI PROVINCE", " VERONA", " CRETE", " ROMA (ROME)", " PADOVA", " GULF OF ISKENDERUN", " SCOTLAND", " SICHUAN PROVINCE", " HINDU-KUSH; KAZAHKSTAN", " TOKKAIDO", " SHAANXI PROVINCE", " ANTAKYA (ANTI ...

# %% [markdown]
# ### 2.2.3. Histogram of earthquakes in the same country and region

# %%
# Number of earthquakes occurred in the same country and region

print(len(univariate_analysis['Name'].unique()))
# Out:
# 3790

# %%
# Names of the regions where more than one earthquake has occurred

multiple_earthquakes = pd.DataFrame(univariate_analysis, columns=['Name'])
multiple_earthquakes_output = multiple_earthquakes[multiple_earthquakes.duplicated()]
print(multiple_earthquakes_output)
# Out:
#                             Name
# 7        ISRAEL: ARIHA (JERICHO)
# 26                        GREECE
# 37    PORTUGAL: CABO SAN VICENTE
# 51                        GREECE
# 55             ISRAEL: PALESTINE
# ...                          ...
# 6139   PAKISTAN: MIRPUR DISTRICT
# 6140    INDONESIA: MALUKU: AMBON
# 6141            TURKEY: ISTANBUL
# 6142        CHILE: SOUTH CENTRAL
# 6143           CHILE: CONCEPCION
#
# [2354 rows x 1 columns]

# %%
# The frequency of earthquakes in each of the regions

print(univariate_analysis['Name'].value_counts())
# Out:
# CHINA: YUNNAN PROVINCE                               79
# TURKEY                                               49
# CHINA: SICHUAN PROVINCE                              48
# RUSSIA: KURIL ISLANDS                                39
# SOLOMON ISLANDS                                      34
#                                                      ..
# GREECE: SAGIADHA-KONISPOLIS (THESPROTIA)              1
# CHINA: SHANXI PROVINCE: LINFEN                        1
# FRANCE: CORRENCON,CHATEAU-BERNARD,LE GUA,RENCUREL     1
# CALIFORNIA: NORTHRIDGE                                1
# FRANCE: TARBES, LOURDES                               1
# Name: Name, Length: 3790, dtype: int64

# %%
# Plotting the histogram

histogram_region = univariate_analysis['Name']
fig = px.histogram(histogram_region, x="Name")
fig.update_layout(
    title_text='Histogram of earthquakes in each country and region', # title of plot
    xaxis_title_text='Name of the Country along with region', # xaxis label
    yaxis_title_text='Count', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig.show()
# Out:
# <div>
#
#
#             <div id="9650b22c-4397-48d8-8200-e06875c1827d" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9650b22c-4397-48d8-8200-e06875c1827d")) {
#                     Plotly.newPlot(
#                         '9650b22c-4397-48d8-8200-e06875c1827d',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Name=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["JORDAN: BAB-A-DARAA,AL-KARAK", "SYRIA: UGARIT", "TURKMENISTAN: W", "GREECE: THERA ISLAND (SANTORINI)", "ISRAEL: ARIHA (JERICHO)", "ITALY: LACUS CIMINI", "SYRIAN COASTS", "ISRAEL: ARIHA (JERICHO)", "JORDAN: SW: TIMNA COPPER MINES", "ISRAEL: JERUSALEM", "LEBANON: SUR (TYRE)", "GREECE: MOUNT TAYGETUS", "LEBANON: SUR (TYRE), SAYDA (SAIDA)", "GREECE: SARONIC GULF", "GREECE: MACEDONIA", "GREECE: ROMAN TERRITORIES", "GREECE: EUBOEA", "IRAN: REY,EIVAN-E-KAY", "GREECE", "ITALY: ROME", "GREECE: AEGEAN SEA", "INDIA: KUTCH", "GREECE: DELPHI", "TURKEY: LYSIMACHIA", "KYRGYZSTAN: CHIGUCHIN", "GREECE: DODECANESE ISLANDS", "GREECE", "EGYPT: SIWA OASIS; LIBYA", "SPAIN: CADIZ", "ITALY: LIGURIA (LIGURIE), GAULE", "PORTUGAL: CABO SAN VICENTE", "EAST MEDITERRANEAN SEA", "CHINA: GANSU PROVINCE: LINTAO", "CHINA: GANSU PROVINCE", "ITALY: SABINES", "CHINA: SHANDONG PROVINCE", "RUSSIA: PANTIKAPEY", "PORTUGAL: CABO SAN VICENTE", "ALBANIA: DYRRACHIUM", "BULGARIA: BISONE [KAVARNA], DIONISOPOLIS [BALCHIK]", "GEORGIA: DYOSCURIA [SUKHUMI]", "CHINA: GANSU PROVINCE: LONGXI", "ISRAEL: PALESTINE", "ISRAEL: QUMRAN,ARIHA (JERICHO)", "EGYPT: THEBES", "CHINA: SICHUAN: YIBIN", "CYPRUS", "CYPRUS: SALAMIS", "TURKMENISTAN: NISA", "TURKEY", "TURKEY: IZMIR, EFES, AYDIN, MANISA, ALASEHIR, SART", "GREECE", "PAKISTAN", "SOUTH KOREA: KWANGJU", "TURKEY: IZNIK,IZMIT", "ISRAEL: PALESTINE", "TURKEY: ANTAKYA (ANTIOCH)", "CHINA: HENAN PROVINCE: NANYANG", "AFGHANISTAN: AIKHANUM", "GREECE: PHILIPPI,DRAMA,KAVALA", "TURKEY: ANTAKYA (ANTIOCH)", "GREECE: CRETE", "ALBANIA: DURRES", "TURKEY: LAODICEA, HIERAPOLIS, COLOSSAE, [PAMUKKALE]", "GREECE: CRETE", "ITALY: POMPEI", "CYPRUS: PAPHOS, SALAMIS", "ITALY: NAPLES (NAPOLI)", "SOUTH KOREA: KWANGJU", "TURKEY: HELLESPONT", "SOUTH KOREA: KYONGJU", "TURKEY", "TURKEY: GALATIA", "TURKEY: ANTAKYA (ANTIOCH)", "TURKEY: NICOMEDIA, NICAEA", "SOUTH KOREA: KYONGJU", "CHINA: GANSU PROVINCE: GANGU", "CHINA: GANSU PROVINCE", "GREECE: RHODES", "CHINA: GANSU PROVINCE", "GREECE: DODECANESE ISLANDS", "GREECE-TURKEY: VITINIA,HELLESPONT", "CHINA: YELLOW SEA", "ITALY: SICILY", "TURKEY: IZMIR, AEGEAN ISLANDS", "CHINA: GANSU PROVINCE", "ITALY: VERONA,BENACO", "GREECE: CRETE", "TURKEY", "ITALY: ROME", "TURKEY: S COASTS; LIBYA", "CHINA: ANHUI PROVINCE: SHOUXIAN", "CHINA: BEIJING", "SOUTH KOREA: KYONGJU", "LEBANON: SUR (TYRE), SAYDA (SAIDA)", "ISRAEL: AEROPOLIS", "CHINA: GANSU PROVINCE: XIHE", "ITALY: CAMPANIA", "ALBANIA: DURRES", "TURKEY: ANTAKYA (ANTIOCH)", "TURKEY: ANTAKYA (ANTIOCH)", "ALBANIA: DURRES", "TURKEY: ANTAKYA (ANTIOCH)", "ITALY: CAMPANIA", "CHINA: HENAN PROVINCE", "TURKEY: DARDANELLES", "ALBANIA: DURRES (DYRRACHIUM)", "LEBANON: BAYRUT (BEROUTH)", "TURKEY", "TURKEY: IZMIT,NICOMEDIA", "TURKEY: IZNIK, IZMIT [NICOMEDIA]", "BALKANS NW: MACEDONIA: STOBI", "JORDAN: AL-KARAK", "TURKEY", "GREECE: CRETE: KNOSSOS", "TURKEY: IZNIK,NICAEA", "TURKEY: NICAEA [IZNIK]", "TURKEY: MARMARA SEA", "ITALY: BENEVENTO", "PORTUGAL: CABO SAN VICENTE: SW", "TURKEY: ANTAKYA (ANTIOCH)", "TURKEY: ANTAKYA (ANTIOCH)", "TURKEY: MARMARA SEA", "TUNISIA: UTIQUE", "ISRAEL: PALESTINE", "ISRAEL: JERUSALEM, PALESTINE, RAMLEH; EGYPT", "AZERBAIJAN", "GREECE: CRETE", "TURKEY: ISTANBUL (CONSTANTINOPLE)", "TURKEY: ISTANBUL (CONSTANTINOPLE)", "GREECE: CRETE", "INSTANBUL (CONSTANTINOPLE)", "TURKEY: ANTAKYA (ANTIOCH)", "TURKEY: ANTAKYA (ANTIOCH)", "THAILAND: YONOK-NAGABANDHU", "FRANCE: VIENNE,VIVARAIS,DAUPHINE,VELAY,FOREZ", "TURKEY: ISTANBUL (CONSTANTINOPLE)", "TURKEY: MARMARA SEA", "LEBANON: TARABULUS (TRIPOLIS); SYRIA", "CHINA: JIANGSU PROVINCE", "KAZAKHSTAN", "NORTH KOREA: PYONGYANG", "SOUTH KOREA: KYONGJU", "CHINA: SHAANXI PROVINCE: YINGXIAN", "BALKANS NW: MACEDONIA: SKOPJE, STAMER", "GREECE: DURRES,KORINTHOS", ...

# %% [markdown]
# ### 2.2.4. Understanding Tsu and Vol columns

# %% [markdown]
# The *Tsu* and *Vol* columns in the dataset represent the occurrence of a tsunami or a volcano. A basic statistical overview of these variables is provided to assess how many tsunamis and volcanoes occurred as a side effect to the earthquakes.

# %%
# Count of tsunami occurrences along with missing value count

tsunami_analysis = univariate_analysis['Tsu'].value_counts()
print(tsunami_analysis)
# Out:
# ?      4291
# Tsu    1853
# Name: Tsu, dtype: int64

# %%
# Count of volcano occurrences along with missing value count

volcano_analysis = univariate_analysis['Vol'].value_counts()
print(volcano_analysis)
# Out:
# ?      6080
# Vol      64
# Name: Vol, dtype: int64

# %% [markdown]
# ## 2.3. Univariate Analysis of Numerical Variables
#
# This section analyzes five numerical variables: Year, Latitude, Longitude, Magnitude, MMI Int, and Updated Year. Briefly, they are:
#
# Year: The year in which the earthquake occurred.
# Latitude and Longitude: Geographical coordinates of the earthquake location.
# Magnitude: The intensity of the earthquake as measured by seismological instruments.
# MMI Int: An ascending order of representation of the occurred damage.
# Updated Year: The offset value of the column *Year*.
#
# This section is further organized as the analysis of following variables:
#
#     2.3.1. Year
#     2.3.2. Latitude and Longitude
#     2.3.3. Magnitude

# %% [markdown]
# ### 2.3.1. Year
#
# The Year values range from -2150 to 2019. Along with a statistical overview of the column, a histogram is represented.

# %%
# Statistical overview of the column 'Year'

univariate_analysis.Year.describe()
# Out:
# count    6144.000000
# mean     1804.691243
# std       376.404999
# min     -2150.000000
# 25%      1820.000000
# 50%      1928.000000
# 75%      1988.000000
# max      2019.000000
# Name: Year, dtype: float64

# %%
# Plotting the histogram

histogram_year = univariate_analysis['Year']
fig = px.histogram(histogram_year, x="Year")
fig.update_layout(
    title_text='Histogram of earthquake occurrence', # title of plot
    xaxis_title_text='Year', # xaxis label
    yaxis_title_text='Count', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig.show()
# Out:
# <div>
#
#
#             <div id="d8b06b20-85fe-4a9b-9673-aa2cf1be8017" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d8b06b20-85fe-4a9b-9673-aa2cf1be8017")) {
#                     Plotly.newPlot(
#                         'd8b06b20-85fe-4a9b-9673-aa2cf1be8017',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [-2150, -2000, -2000, -1610, -1566, -1450, -1365, -1250, -1050, -759, -590, -550, -525, -480, -479, -432, -426, -400, -373, -364, -330, -326, -282, -282, -250, -227, -223, -221, -218, -217, -210, -198, -193, -186, -177, -70, -63, -60, -58, -50, -50, -47, -33, -31, -27, -26, -26, -15, 10, 11, 17, 23, 25, 27, 29, 33, 37, 46, 50, 52, 52, 55, 57, 60, 62, 63, 76, 79, 89, 93, 100, 105, 109, 115, 120, 123, 128, 138, 142, 143, 155, 170, 173, 177, 177, 180, 243, 251, 253, 258, 262, 294, 294, 304, 306, 315, 319, 324, 334, 340, 341, 342, 342, 344, 344, 344, 346, 348, 350, 355, 358, 361, 362, 362, 365, 367, 368, 368, 369, 382, 394, 396, 407, 412, 419, 425, 427, 438, 440, 447, 448, 450, 457, 458, 460, 470, 477, 478, 494, 499, 500, 501, 510, 512, 518, 521, 522, 522, 525, 527, 528, 533, 543, 551, 551, 551, 552, 553, 554, 555, 557, 557, 557, 558, 558, 565, 567, 579, 581, 587, 600, 614, 634, 649, 662, 664, 678, 684, 688, 701, 704, 713, 715, 716, 734, 735, 740, 742, 743, 743, 744, 745, 745, 746, 748, 749, 758, 763, 766, 777, 778, 778, 780, 788, 793, 796, 801, 802, 803, 811, 814, 818, 818, 820, 835, 838, 842, 844, 845, 846, 847, 847, 847, 850, 850, 851, 853, 854, 854, 854, 855, 856, 856, 856, 856, 857, 858, 858, 859, 860, 863, 863, 863, 863, 864, 867, 869, 871, 876, 881, 885, 887, 887, 891, 893, 894, 896, 896, 898, 910, 912, 922, 942, 942, 943, 951, 953, 956, 957, 957, 958, 958, 963, 972, 977, 978, 985, 986, 990, 991, 999, 999, 1000, 1000, 1001, 1001, 1003, 1003, 1007, 1008, 1010, 1013, 1021, 1022, 1026, 1033, 1036, 1037, 1038, 1039, 1040, 1042, 1042, 1045, 1046, 1048, 1052, 1052, 1057, 1058, 1063, 1063, 1064, 1065, 1065, 1066, 1067, 1068, 1068, 1070, 1072, 1076, 1082, 1085, 1085, 1086, 1086, 1088, 1088, 1089, 1091, 1096, 1099, 1101, 1102, 1102, 1106, 1109, 1111, 1114, 1114, 1114, 1115, 1115, 1115, 1117, 1117, 1118, 1119, 1125, 1125, 1130, 1130, 1137, 1137, 1139, 1143, 1149, 1151, 1151, 1153, 1155, 1155, 1156, 1157, 1158, 1160, 1164, 1169, 1169, 1171, 1172, 1175, 1175, 1176, 1179, 1180, 1182, 1182, 1183, 1184, 1201, 1202, 1202, 1208, 1208, 1209, 1209, 1211, 1219, 1222, 1222, 1223, 1227, 1227, 1231, 1231, 1233, 1237, 1237, 1237, 1241, 1248, 1255, 1257, 1257, 1259, 1267, 1268, 1269, 1272, 1273, 1273, 1275, 1276, 1277, 1279, 1280, 1280, 1280, 1281, 1283, 1284, 1286, 1289, 1289, 1290, 1291, 1291, 1293, 1293, 1295, 1295, 1298, 1300, 1300, 1300, 1301, 1303, 1303, 1304, 1305, 1306, 1306, 1306, 1310, 1310, 1314, 1319, 1319, 1320, 1323, 1327, 1328, 1329, 1331, 1332, 1336, 1336, 1337, 1339, 1340, 1341, 1341, 1343, 1343, 1343, 1344, 1344, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1352, 1353, 1354, 1356, 1356, 1358, 1359, 1360, 1360, 1361, 1361, 1361, 1365, 1367, 1368, 1372, 1374, 1375, 1377, 1380, 1382, 1383, 1384, 1385, 1386, 1387, 1387, 1389, 1389, 1389, 1389, 1390, 1390, 1391, 1399, 1400, 1400, 1402, 1403, 1403, 1404, 1405, 1406, 1407, 1408, 1408, 1414, 1417, 1418, 1419, 1426, 1427, 1428, 1431, 1433, 1440, 1440, 1441, 1441, 1443, 1444, 1444, 1445, 1447, 1448, 1451, 1454, 1454, 1455, 1456, 1456, 1456, 1457, 1458, 1458, 1459, 1461, 1461, 1463, 1464, 1469, 1471, 1471, 1475, 1478, 1479, 1481, 1481, 1481, 1481, 1481, 1482, 1482, 1482, 1483, 1483, 1484, 1484, 1485, 1487, 1488, 1489, 1490, 1490, 1490, 1491, 1493, 1493, 1494, 1494, 1494, 1494, 1495, 1495, 1496, 1498, 1498, 1498, 1498, 1499, 1500, 1500, 1501, 1501, 1502, 1502, 1502, 1504, 1504, 1504, 1505, 1505, 1505, 1507, 1508, 1509, 1509, 1509, 1509, 1509, 1510, 1510, 1510, 1510, 1511, 1511, 1511, 1512, 1512, 1513, 1514, 1514, 1515, 1515, 1516, 1516, 1516, 1517, 1518, 1518, 1520, 1520, 1520, 1522, 1522, 1523, 1524, 1527, 1530, 1530, 1531, 1531, 1535, 1536, 1537, 1538, 1538, 1539, 1539, 1541, 1542, 1542, 1542 ...

# %% [markdown]
# ### 2.3.2. Latitude and Longitude
#
# Latitudes and longitudes range from -90 to +90 each. This section contains the following subsections:
#
#     2.3.2.1. Minimum latitude
#     2.3.2.2. Maximum latitude
#     2.3.2.3. Minimum longitude
#     2.3.2.4. Maximum longitude
#     2.3.2.5. Entries with same latitude and longitude

# %% [markdown]
# #### 2.3.2.1. Minimum latitude

# %%
# Finding the minimum latitude value

print(univariate_analysis['Latitude'].min())
# Out:
# -62.877

# %%
# Accessing the index of that value

latitude_min = univariate_analysis.loc[univariate_analysis['Latitude'] == '-0.018000000000000002']
print(latitude_min)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Tsu, Vol, Name, Latitude, Longitude, Mag, MMI Int, Country, Region, UpdatedYear]
# Index: []

# %% [markdown]
# #### 2.3.2.2. Maximum latitude

# %%
# Finding maximum latitude

print(univariate_analysis['Latitude'].max())
# Out:
# 73.122

# %% [markdown]
# The output is incorrect since question marks(?) were added to replace missing values. In order to arrive at the right answer, the rows with '?' are dropped and the result is stored in another dataframe. The maximum value of this new dataframe is then calculated.

# %%
# Creating a new dataframe with all the values except the missing entries in Latitude column

latitude_max = univariate_analysis[univariate_analysis.Latitude != '?']

# Printing the maximum latitude

print(latitude_max.max())
# Out:
# Unnamed: 0               6143
# Year                     2019
# Tsu                       Tsu
# Vol                       Vol
# Name           ZAMBIA: KAPUTA
# Latitude               73.122
# Longitude                 180
# Mag                         ?
# MMI Int                     ?
# Country                ZAMBIA
# UpdatedYear              4169
# dtype: object

# %% [markdown]
# #### 2.3.2.3. Minimum longitude

# %%
# Finding the minimum longitude value

print(univariate_analysis['Longitude'].min())
# Out:
# -179.984

# %%
# Accessing the index of that value

longitude_min = univariate_analysis.loc[univariate_analysis['Longitude'] == '-0.05']
print(longitude_min)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Tsu, Vol, Name, Latitude, Longitude, Mag, MMI Int, Country, Region, UpdatedYear]
# Index: []

# %% [markdown]
# #### 2.3.2.4. Maximum Longitude

# %%
# Finding maximum longitude

print(univariate_analysis['Longitude'].max())
# Out:
# 180.0

# %% [markdown]
# A similar problem as latitude is faced.  In order to arrive at the right answer, the rows with '?' are dropped and the result is stored in another dataframe. The maximum value of this new dataframe is then calculated.

# %%
# Creating a new dataframe with all the values except the missing entries in longitude column

longitude_max = univariate_analysis[univariate_analysis.Longitude != '?']

# Printing the maximum longitude

print(longitude_max.max())
# Out:
# Unnamed: 0               6143
# Year                     2019
# Tsu                       Tsu
# Vol                       Vol
# Name           ZAMBIA: KAPUTA
# Latitude               73.122
# Longitude                 180
# Mag                         ?
# MMI Int                     ?
# Country                ZAMBIA
# UpdatedYear              4169
# dtype: object

# %% [markdown]
# #### 2.3.2.5. Entries with same latitude and longitude
#
# The next piece of code is aimed at understanding if there were multiple earthquakes in exactly the same geographical coordinates.

# %%
# Creating a new dataframe with latitude and longitude values from the main dataframe univariate_analysis

multiple_earthquakes = pd.DataFrame(univariate_analysis, columns=['Latitude', 'Longitude'])

# Creating another dataframe with only the duplicate values from multiple_earthquakes

rows = multiple_earthquakes[multiple_earthquakes.duplicated()]
print(rows)
# Out:
#       Latitude  Longitude
# 6       35.683     35.800
# 15      37.000     22.500
# 34       0.000      0.000
# 43      32.000     35.500
# 60      36.100     36.100
# ...        ...        ...
# 4198    -5.000    130.000
# 4205   -29.900    -71.300
# 4276    39.000     44.000
# 4307     0.000      0.000
# 5530    23.970     97.569
#
# [721 rows x 2 columns]

# %% [markdown]
# The output is incorrect since missing values exist. The rows which have either latitude or longitdue, or both are dropped.

# %%
# Creating a new dataframe by excluding missing values from Longitude column

rows_updated_longitude = rows[rows.Longitude != '?']
#print(rows_updated_longitude)

# Creating a new dataframe by excluding missing values from rows_updated_longitude

rows_updated_latitude = rows[rows.Latitude != '?']
print(rows_updated_latitude)
# Out:
#       Latitude  Longitude
# 6       35.683     35.800
# 15      37.000     22.500
# 34       0.000      0.000
# 43      32.000     35.500
# 60      36.100     36.100
# ...        ...        ...
# 4198    -5.000    130.000
# 4205   -29.900    -71.300
# 4276    39.000     44.000
# 4307     0.000      0.000
# 5530    23.970     97.569
#
# [721 rows x 2 columns]

# %% [markdown]
# ### 2.3.3. Magnitude
#
# Magnitude represents the energy released from the earthquake at its source. This section contains:
#
#     2.3.3.1. Minimum magnitude
#     2.3.3.2. Maximum magnitude
#     2.3.3.3. Frequency of magnitudes
#     2.3.3.4. Histogram of magnitudes

# %%
# Overview of the magnitude column

print(univariate_analysis['Mag'].describe())
# Out:
# count     6144
# unique      65
# top          ?
# freq      1783
# Name: Mag, dtype: object

# %% [markdown]
# #### 2.3.3.1. Minimum magnitude

# %%
# Finding the minimum magnitude

print(univariate_analysis['Mag'].min())
# Out:
# 1.6

# %%
# Accessing the entire row of this magnitude

magnitude_min = univariate_analysis.loc[univariate_analysis['Mag'] == '1.6']
print(magnitude_min)
# Out:
#       Unnamed: 0  Year Tsu Vol  Name  Latitude  Longitude  Mag MMI Int  \
# 5427        5427  2007   ?   ?  UTAH    39.464   -111.207  1.6       ?
#
#      Country Region  UpdatedYear
# 5427    UTAH    NaN         4157

# %% [markdown]
# #### 2.3.3.2. Maximum magnitude

# %%
# Creating a new dataframe my excluding missing entries from Mag column 

magnitude_maximum = univariate_analysis[univariate_analysis.Mag != '?']

# Printing the maximum value of the Mag column in the new dataframe

print(magnitude_maximum.Mag.max())
# Out:
# 9.5

# %%
# Accessing the entire row of this magnitude


magnitude_max = univariate_analysis.loc[univariate_analysis['Mag'] == '9.5']
print(magnitude_max)
# Out:
#       Unnamed: 0  Year  Tsu  Vol                           Name  Latitude  \
# 3775        3775  1960  Tsu  Vol  CHILE: PUERTO MONTT, VALDIVIA   -38.143
#
#       Longitude  Mag MMI Int Country                   Region  UpdatedYear
# 3775    -73.407  9.5    12.0   CHILE   PUERTO MONTT, VALDIVIA         4110

# %% [markdown]
# #### 2.3.3.3. Frequency of magnitudes

# %%
# Counting the frequency of earthquake magnitudes

magnitude_count = univariate_analysis['Mag'].value_counts()
print(magnitude_count)
# Out:
# ?      1783
# 7.5     259
# 7.0     224
# 6.0     203
# 6.5     199
#        ...
# 3.7       2
# 9.5       1
# 2.2       1
# 9.2       1
# 1.6       1
# Name: Mag, Length: 65, dtype: int64

# %%
# Frequency of magnitudes in ascending order

print(univariate_analysis.groupby('Mag').size())
# Out:
# Mag
# 1.6       1
# 2.1       2
# 2.2       1
# 3.1       3
# 3.2       4
#        ...
# 9.0       2
# 9.1       3
# 9.2       1
# 9.5       1
# ?      1783
# Length: 65, dtype: int64

# %% [markdown]
# #### 2.3.3.4. Histogram of magnitudes

# %%
histogram_region = univariate_analysis['Mag']
fig = px.histogram(histogram_region, x="Mag")
fig.update_layout(
    title_text='Histogram of magnitudes', # title of plot
    xaxis_title_text='Magnitude number', # xaxis label
    yaxis_title_text='Count', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)
fig.show()
# Out:
# <div>
#
#
#             <div id="e701e233-8830-49f4-9c5d-efaffcded834" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e701e233-8830-49f4-9c5d-efaffcded834")) {
#                     Plotly.newPlot(
#                         'e701e233-8830-49f4-9c5d-efaffcded834',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Mag=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["7.3", "?", "7.1", "?", "?", "?", "?", "6.5", "6.2", "?", "?", "?", "?", "?", "7.0", "?", "7.1", "7.6", "7.3", "?", "7.0", "?", "?", "?", "6.7", "7.2", "?", "?", "?", "?", "?", "?", "6.5", "7.0", "?", "7.0", "6.4", "6.7", "6.6", "?", "5.5", "?", "?", "7.0", "?", "5.5", "?", "?", "7.1", "?", "?", "?", "?", "6.3", "?", "?", "?", "6.5", "?", "?", "?", "?", "?", "?", "6.9", "?", "?", "?", "6.3", "?", "6.3", "?", "?", "7.5", "7.2", "6.3", "6.5", "6.8", "7.0", "7.0", "?", "?", "?", "?", "?", "7.5", "5.3", "?", "?", "?", "?", "5.5", "5.5", "6.3", "?", "?", "4.5", "?", "?", "?", "?", "?", "?", "?", "?", "?", "6.8", "?", "?", "?", "?", "?", "6.4", "?", "8.0", "?", "?", "6.4", "?", "?", "?", "?", "6.6", "?", "?", "?", "6.7", "?", "?", "7.3", "?", "?", "?", "?", "?", "?", "?", "7.2", "?", "?", "6.7", "6.3", "6.3", "7.5", "?", "?", "?", "?", "7.0", "?", "7.1", "?", "6.8", "?", "7.1", "?", "?", "?", "7.0", "?", "?", "?", "7.0", "7.0", "?", "?", "?", "?", "?", "?", "?", "?", "?", "5.5", "?", "6.3", "?", "8.4", "?", "7.0", "7.0", "?", "?", "?", "7.0", "5.8", "7.3", "?", "7.2", "5.5", "6.4", "7.9", "6.5", "7.0", "?", "?", "?", "7.6", "6.5", "?", "?", "5.6", "6.3", "6.5", "?", "?", "?", "?", "?", "?", "7.0", "7.5", "7.9", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "7.0", "5.2", "?", "?", "?", "?", "?", "4.5", "?", "7.9", "?", "?", "5.2", "?", "?", "?", "?", "4.9", "7.0", "?", "?", "?", "8.6", "6.8", "6.5", "?", "?", "6.5", "8.6", "6.3", "?", "5.3", "?", "?", "?", "?", "?", "7.0", "6.7", "?", "?", "?", "7.1", "?", "?", "?", "?", "?", "?", "?", "?", "5.3", "?", "?", "?", "?", "?", "5.5", "?", "?", "?", "6.0", "?", "4.2", "?", "6.5", "?", "?", "?", "6.5", "7.5", "?", "5.7", "?", "7.3", "6.8", "?", "?", "7.6", "?", "5.5", "?", "?", "?", "6.8", "?", "?", "?", "?", "?", "?", "?", "6.8", "?", "6.0", "?", "?", "?", "?", "?", "?", "?", "?", "5.3", "7.0", "?", "?", "8.4", "8.4", "6.5", "?", "6.1", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "6.5", "7.0", "?", "?", "?", "?", "?", "?", "6.0", "?", "?", "6.2", "?", "?", "?", "?", "?", "?", "6.1", "?", "?", "?", "?", "?", "?", "7.1", "?", "?", "?", "?", "6.7", "?", "?", "?", "7.6", "?", "6.5", "6.1", "6.3", "7.6", "?", "6.5", "?", "?", "?", "5.5", "?", "6.9", "?", "5.6", "?", "?", "?", "7.0", "?", "?", "7.0", "7.5", "?", "5.8", "?", "?", "?", "6.5", "?", "6.7", "?", "5.1", "?", "?", "?", "?", "5.8", "6.3", "?", "?", "?", "?", "6.8", "?", "6.5", "?", "7.1", "?", "?", "?", "?", "6.5", "?", "?", "8.0", "8.0", "6.7", "6.5", "6.5", "?", "?", "?", "5.5", "6.0", "?", "?", "?", "?", "4.8", "?", "?", "7.0", "?", "?", "7.6", "6.5", "?", "?", "6.0", "7.0", "?", "?", "7.5", "?", "?", "?", "?", "?", "?", "?", "?", "6.5", "5.5", "7.0", "?", "?", "?", "?", "?", "?", "?", "7.0", "?", "?", "8.4", "5.0", "?", "?", "6.0", "4.8", "?", "?", "?", "?", "?", "?", "?", "6.3", "?", "?", "?", "5.8", "?", "7.6", "?", "6.1", "?", "?", "?", "?", "?", "?", "?", "7.0", "?", "6.7", "6.2", "?", "7.0", "?", "?", "?", "?", "?", "?", "?", "?", "?", "7.1", "6.3", "6.5", "?", "?", "?", "?", "?", "6.3", "?", "7.0", "?", "?", "?", "6.3", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "?", "8.0", "6.4", "5.5", "?", "7.1", "6.0", "?", "?", "?", "?", "6.5", "7.5", "7.7", "?", "6.8", "?", "6.5", "6.3", "5.5", "?", "5.8", "?", "?", "?", "6.5", "?", "5.5", "?", "?", "7.2", "6.3", "7.1", "?", "6.4", "?", "8.3", "7.5", "?", "?", "?", "7.0", "?", "?", "6.5", "?", "?", "?", "?", "?", "5.0", "?", "5.3", "?", "?", "?", "7.7", "?", "?", "?", "6.7", "7.0", "?", "6.5", "?", "5.8", "6.5", "?", "8.7", "?", "5.5", "7.0", "?", "?", "?", "?", "5.5", "6.7", "?", "5.5", "7.0", "?", "?", "?", "?", "?", "?", "?", "8.0", "7.7", "4.8", "5.0",  ...

# %%
import plotly.graph_objects as go

labels = ['Magnitude']
values = univariate_analysis['Mag'].unique()
print(len(values))
# Out:
# 65

# %%
# A pie chart of the distribution of magnitudes

fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
fig.show()
# Out:
# <div>
#
#
#             <div id="e2473ebf-4c60-4025-a252-32fbaf9c5c3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2473ebf-4c60-4025-a252-32fbaf9c5c3a")) {
#                     Plotly.newPlot(
#                         'e2473ebf-4c60-4025-a252-32fbaf9c5c3a',
#                         [{"labels": ["Magnitude"], "type": "pie", "values": ["7.3", "?", "7.1", "6.5", "6.2", "7.0", "7.6", "6.7", "7.2", "6.4", "6.6", "5.5", "6.3", "6.9", "7.5", "6.8", "5.3", "4.5", "8.0", "8.4", "5.8", "7.9", "5.6", "5.2", "4.9", "8.6", "6.0", "4.2", "5.7", "6.1", "5.1", "4.8", "5.0", "7.7", "8.3", "8.7", "7.8", "8.5", "8.2", "5.9", "5.4", "8.1", "7.4", "9.0", "3.2", "8.8", "9.1", "4.1", "4.3", "4.0", "4.7", "9.5", "4.6", "9.2", "4.4", "3.5", "3.8", "3.7", "2.2", "3.9", "1.6", "3.4", "3.1", "2.1", "3.6"]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ## 2.4. Insights
#
# ### Univariate analysis of categorical variables
#
#     1. There are four categorical variables:  Country, Region, Tsu, and Vol.
#
# #### Country
#
#     1. 340 unique countries have experienced significant earthquakes in the duration -2150 to 2019.
#     2. Out of these 341 countries, China is seen to have the highest number of earthquakes (598) during the entire duration from -2150 to 2019. The trend in its count is analyzed in greater detail in the multivariate section.
#
# #### Region
#
#     1. 2873 unique regions have experienced earthquakes during the years -2150 to 2019.
#     2. 1950-1999 experienced the highest number of eathquakes: 1464.
#     3. Out of these, Yunnan Province in China has the highest number of earthquakes.
#     4. 2353 unique places have experienced more than one earthquake in the same country and region.
#
# #### Tsu and Vol
#
#     1. There are 1853 occurrences of tsunamis and 64 of volcanoes.
#     2. There are 6080 missing entries for Vol, which means either the volcano did not occur or was not documented.
#
#
# ### Univariate analysis of numerical variables
#
# #### Year
#
#     1. Years 1950 - 1999 experienced the maximum number of earthquakes: 1464
#
# #### Latitude and Longitude
#
#     1. Ecuador: Quito experienced a 5.5 magnitude earthquake in 2014 and was the place with minimum latitude of    -0.098000000000000002.
#     2. Zambia: Kaputa experienced an earthquake in 2019 and was the place with maximum latitude of 9.999.
#     3. France: Pyrenees experienced a 4.7 magnitude earthquake in 2006 and was the place with minimum longitude of -0.05.
#     4. Zambia: Kaputa experienced another earthquake in 2019 and was the place with maximum latitude of 99.9.
#     5. 673 unique geographical locations experienced more than one earthquake.
#
# #### Magnitude
#
#     1. Earthquakes of magnitude 7.5 are the most frequent ones that have occurred 259 times.
#     2. Utah experienced the lowest magnitude earthquake of 1.6 in 2007.
#     3. Chile: Peurto Montt experienced the highest magnitude earthquake of 9.5 in 1960.
